# %% [markdown]
# <a href="https://colab.research.google.com/github/KovvadaHaritha/fmml_labs_projects/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 04:57:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   151MB/s    in 0.5s
#
# 2024-03-26 04:57:05 (151 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21716   1010.4945v1  A density ratio is defined by the ratio of two...  stat
# 20487  1603.08869v1  Hierarchical Reinforcement Learning (HRL) expl...    cs
# 17565  1712.03376v2  Recently, Yuan et al. (2016) have shown the ef...    cs
# 39630  1610.09908v1  This article describes the implementation of t...    cs
# 25096  1504.06740v1  This paper studies the robustness of SIFT and ...    cs
# ...             ...                                                ...   ...
# 10587   1309.4844v1  We present five methods to the problem of netw...  stat
# 22879  1710.00109v1  We consider the problem of reconstructing sign...  stat
# 7525   1802.00043v1  Incremental versions of batch algorithms are o...  stat
# 15398   1412.1215v1  In the following article we elected to study w...    cs
# 18578   1106.0246v1  The chief aim of this paper is to propose mean...    cs
#
#                                                    title  year  \
# 21716  f-divergence estimation and two-sample homogen...  2010
# 20487  Algorithms for Batch Hierarchical Reinforcemen...  2016
# 17565  Word Sense Disambiguation with LSTM: Do We Rea...  2017
# 39630  Joint Large-Scale Motion Estimation and Image ...  2016
# 25096  SIFT Vs SURF: Quantifying the Variation in Tra...  2015
# ...                                                  ...   ...
# 10587  Network Anomaly Detection: A Survey and Compar...  2013
# 22879  Reconstruction from Periodic Nonlinearities, W...  2017
# 7525       Incremental kernel PCA and the Nyström method  2018
# 15398  Mary Astell's words in A Serious Proposal to t...  2014
# 18578  Mean Field Methods for a Special Class of Beli...  2011
#
#                                                 keywords
# 21716  [probability, densities, inference, parametric...
# 20487  [hierarchical, reinforcement, abstraction, pro...
# 17565  [effectiveness, performing, disambiguation, te...
# 39630  [describes, implementation, estimation, recons...
# 25096  [robustness, different, transforms, similarity...
# ...                                                  ...
# 10587  [detection, techniques, detection, including, ...
# 22879  [reconstructing, nonlinearities, measurement, ...
# 7525   [incremental, algorithms, increased, efficienc...
# 15398  [following, published, semantics, vindication,...
# 18578  [approximations, approximations, suggested, ap...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21716    [probability, densities, inference, parametric...
# 20487    [hierarchical, reinforcement, abstraction, pro...
# 17565    [effectiveness, performing, disambiguation, te...
# 39630    [describes, implementation, estimation, recons...
# 25096    [robustness, different, transforms, similarity...
#                                ...
# 5414     [reinforcement, preference, elicitation, resul...
# 10396    [processing, literature, motivated, clustering...
# 16797    [paraphrastic, embeddings, translation, senten...
# 5800     [uncertainty, structures, posteriori, estimati...
# 12153    [dimensional, stochastic, approximation, algor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8754 words.
# Out of those 4566 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7b0b3de9-2b48-4883-98cc-4ee69d89b5e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b0b3de9-2b48-4883-98cc-4ee69d89b5e2")) {                    Plotly.newPlot(                        "7b0b3de9-2b48-4883-98cc-4ee69d89b5e2",                        [{"x":["asymptotic","investigate","estimation","illustrate","likelihood","semiparametric","empirical","divergence","exploited","densities","estimated","parametric","estimator","homogeneity","numerical","procedure","probability","inference","convergence","iteration","comparison","introduce","structures","algorithms","behavioral","stochastic","different","effectively","hierarchical","recursive","processes","collected","demonstrate","experiments","reinforcement","converges","transferable","algorithm","decomposition","abstraction","technique","reproduction","performing","effectiveness","disambiguation","benchmarks","available","outperformed","regularizer","connected","underlying","variational","consecutive","presented","components","minimization","implementation","alternating","reconstruction","framework","additional","describes","functional","regularity","evaluation","techniques","variation","performed","resulting","quantitatively","capability","robustness","deformation","exhaustive","analyzing","similarity","transformation","parameters","establishes","transforms","transformations","quantifying","comparing","variations","tolerance","deformations","particular","platforms","mentioned","extracted","information","answering","recurrent","baselines","regression","sentiment","constrained","discussed","strategies","dimensions","guaranteeing","diagnoses","sequential","inexpensive","selection","considered","inferences","reduction","diagnosis","independently","optimized","decoupling","measurement","complexity","polynomial","properties","computations","requiring","instantly","optimizations","clustering","discovering","insensitive","insensitivity","generated","bandwidth","especially","determination","parameter","challenging","remarkable","reliability","structure","multitask","potential","advantage","independent","representation","beneficial","established","representations","dimensionality","important","multilayer","intrinsic","justification","applications","reproducing","illustrated","conditions","theoretical","classifier","principled","optimization","corrective","implemented","optimally","detection","performance","classification","objective","extremely","generation","classifiers","asymmetric","requirement","experimental","addressing","explicitly","optimizes","efficient","architecture","localization","convolutional","invariance","architectures","annotations","approaches","traditional","refinement","computational","outperforms","requirements","recognition","continuous","currently","knowledge","undiscovered","implement","unlabeled","exploration","heuristics","furthermore","consequence","generalization","approximations","principle","annotation","continuously","geography"],"y":[18,171,199,78,66,0,164,33,30,10,57,25,21,2,71,128,175,212,103,37,122,333,138,597,14,130,704,115,109,25,111,74,558,569,95,32,8,822,55,25,253,4,72,201,15,87,312,15,20,86,122,56,14,191,115,65,130,28,103,522,109,78,60,9,267,365,69,129,136,31,52,97,16,8,58,139,59,254,14,19,48,12,74,74,3,19,268,29,20,128,686,48,144,50,138,41,49,73,109,35,4,7,92,7,145,131,12,91,44,55,50,7,33,234,55,229,44,48,5,4,136,14,4,2,182,10,126,9,115,252,28,19,363,5,147,102,127,373,21,61,225,49,355,15,38,10,440,11,20,130,162,157,22,315,3,104,21,345,905,520,169,52,157,129,13,28,370,21,68,15,415,236,55,388,25,108,66,443,197,19,279,251,54,412,87,55,349,3,78,40,64,39,178,17,107,35,56,56,22,2],"type":"bar"},{"x":["asymptotic","investigate","estimation","illust ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4566,), (4566, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.79

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fully</span> <span style=''>Point</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.6133056133056132);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>for</span> <span style=''>Modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3072164948453609);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>Regularities</span> <span style=''>in</span> <span style=''>Natural</span> <span style=''>Images</span> <br/><br/><span style=''>Modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3072164948453609);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>regularities</span> <span style=''>is</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.44329896907216493);'>representing</span> <span style=''>the</span> <span style=''>pixel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>images</span> <span style=''>and</span> <span style=''>usually</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>ill</span> <span style=''>posed</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.423469387755102);'>processing</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>CNN</span> <span style='background-color:rgba(0, 255, 0, 0.5128205128205128);'>architecture</span> <span style=''>for</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3072164948453609);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>regularities</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>that</span> <span style=''>by</span> <span style=''>random</span> <span style=''>sampling</span> <span style=''>the</span> <span style=''>pixels</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>images</span> <span style=''>we</span> <span style=''>can</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>pixel</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>ensembles</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>pixel</span> <span style=''>value</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>using</span> <span style=''>11</span> <span style=''>(point</span> <span style=''>wise)</span> <span style='background-color:rgba(0, 255, 0, 0.47692307692307684);'>convolution</span> <span style=''>kernel</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>kk</span> <span style='background-color:rgba(0, 255, 0, 0.47692307692307684);'>convolution</span> <span style=''>kernel</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>feature</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Matrix</span> <span style=''>valued</span> <span style=''>Kernel</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>and</span> <span style=''>Granger</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Causality</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>matrix</span> <span style=''>valued</span> <span style=''>multiple</span> <span style=''>kernel</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>allows</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style=''>mixed</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>those</span> <span style=''>that</span> <span style=''>induce</span> <span style=''>sparsity</span> <span style=''>to</span> <span style=''>be</span> <span style=''>imposed</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>of</span> <span style=''>vector</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Spaces</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>highly</span> <span style=''>scalable</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigendecomposition</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>orchestrates</span> <span style=''>two</span> <span style=''>inexact</span> <span style=''>solvers</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>learning</span> <span style=''>both</span> <span style=''>the</span> <span style=''>input</span> <span style=''>and</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separable</span> <span style=''>matrix</span> <span style=''>valued</span> <span style=''>kernels</span> <span style=''>As</span> <span style=''>a</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>enabled</span> <span style=''>by</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>tasks</span> <span style=''>can</span> <span style=''>be</span> <span style='background-col ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Reexamining</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.32283464566929126);'>Factorization</span> <span style=''>for</span> <span style=''>Trace</span> <span style=''>Norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Regularization</span> <br/><br/><span style=''>Trace</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>is</span> <span style=''>a</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>A</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>formulating</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>one</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.32283464566929126);'>factorization</span> <span style=''>which</span> <span style=''>however</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>practice</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>works</span> <span style=''>well</span> <span style=''>and</span> <span style=''>it</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>standard</span> <span style=''>convex</span> <span style=''>solvers</span> <span style=''>such</span> <span style=''>as</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444444);'>Nevertheless</span> <span style=''>it</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>a</span> <span style=''>global</span> <span style=''>optimum</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>can</span> <span style=''>be</span> <span style=''>trapped</span> <span style=''>at</span> <span style=''>poor</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695665);'>stationary</span> <span style=''>points</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>all</span> <span style=''>critical</span> <span style=''>points</span> <span style=''>of</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>problem</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>Graph</span> <span style=''>Fourier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transform</span> <br/><br/><span style=''>Many</span> <span style=''>signals</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Cartesian</span> <span style=''>product</span> <span style=''>graphs</span> <span style=''>appear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>such</span> <span style=''>as</span> <span style=''>digital</span> <span style=''>images</span> <span style=''>sensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>time</span> <span style=''>series</span> <span style=''>and</span> <span style=''>movie</span> <span style=''>ratings</span> <span style=''>on</span> <span style=''>Netflix</span> <span style=''>These</span> <span style=''>signals</span> <span style=''>are</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>and</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>directional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>along</span> <span style=''>each</span> <span style=''>factor</span> <span style=''>graph</span> <span style=''>However</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>graph</span> <span style=''>Fourier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>does</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguish</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>directions</span> <span style=''>and</span> <span style=''>assigns</span> <span style=''>1</span> <span style=''>D</span> <span style=''>spectra</span> <span style=''>to</span> <span style=''>signals</span> <span style=''>on</span> <span style=''>product</span> <span style=''>graphs</span> <span style=''>Further</span> <span style=''>these</span> <span style=''>spectra</span> <span style=''>are</span> <span style=''>often</span> <span style=''>multi</span> <span style=''>valued</span> <span style=''>at</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequencies</span> <span style=''>Our</span> <span style=''>main</span> <span style=''>result</span> <span style=''>is</span> <span style=''>a</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>graph</span> <span style=''>Fourier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>that</span> <span style=''>solves</span> <span style=''>such</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>GFT</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algebraic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Cartesian</span> <span style=''>products</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>rearranges</span> <span style=''>1</span> <span style=''>D</span> <span style=''>spectra</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>GFT</span> <span style=''>into</span> <span style=''>the</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08434596140100072)
# 	experimental (0.1322373123659757)
# 	knowledge (0.12473195139385275)
# 	segmentation (0.0725518227305218)
# 	representation (0.1333095067905647)
# 	information (0.24517512508934952)
# 	different (0.2516082916368835)
# 	detection (0.12330235882773409)
# 	convolutional (0.13867047891350964)
# 	recognition (0.1472480343102216)
#
# Some Statistics words are:
# 	variables (0.13036963036963037)
# 	stochastic (0.13836163836163837)
# 	algorithm (0.38611388611388614)
# 	distribution (0.17932067932067933)
# 	statistical (0.15834165834165834)
# 	theoretical (0.15834165834165834)
# 	estimation (0.17382617382617382)
# 	inference (0.1938061938061938)
# 	dimensional (0.19480519480519481)
# 	regression (0.1798201798201798)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="54536c39-0b8a-4e56-a07c-01cab9f15426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54536c39-0b8a-4e56-a07c-01cab9f15426")) {                    Plotly.newPlot(                        "54536c39-0b8a-4e56-a07c-01cab9f15426",                        [{"x":["asymptotic","investigate","estimation","illustrate","likelihood","semiparametric","empirical","divergence","exploited","densities","estimated","parametric","estimator","homogeneity","numerical","procedure","probability","inference","convergence","iteration","comparison","introduce","structures","algorithms","behavioral","stochastic","different","effectively","hierarchical","recursive","processes","collected","demonstrate","experiments","reinforcement","converges","transferable","algorithm","decomposition","abstraction","technique","reproduction","performing","effectiveness","disambiguation","benchmarks","available","outperformed","regularizer","connected","underlying","variational","consecutive","presented","components","minimization","implementation","alternating","reconstruction","framework","additional","describes","functional","regularity","evaluation","techniques","variation","performed","resulting","quantitatively","capability","robustness","deformation","exhaustive","analyzing","similarity","transformation","parameters","establishes","transforms","transformations","quantifying","comparing","variations","tolerance","deformations","particular","platforms","mentioned","extracted","information","answering","recurrent","baselines","regression","sentiment","constrained","discussed","strategies","dimensions","guaranteeing","diagnoses","sequential","inexpensive","selection","considered","inferences","reduction","diagnosis","independently","optimized","decoupling","measurement","complexity","polynomial","properties","computations","requiring","instantly","optimizations","clustering","discovering","insensitive","insensitivity","generated","bandwidth","especially","determination","parameter","challenging","remarkable","reliability","structure","multitask","potential","advantage","independent","representation","beneficial","established","representations","dimensionality","important","multilayer","intrinsic","justification","applications","reproducing","illustrated","conditions","theoretical","classifier","principled","optimization","corrective","implemented","optimally","detection","performance","classification","objective","extremely","generation","classifiers","asymmetric","requirement","experimental","addressing","explicitly","optimizes","efficient","architecture","localization","convolutional","invariance","architectures","annotations","approaches","traditional","refinement","computational","outperforms","requirements","recognition","continuous","currently","knowledge","undiscovered","implement","unlabeled","exploration","heuristics","furthermore","consequence","generalization","approximations","principle","annotation","continuously","geography","linguistic","attributable","composition","individual","geographically","population","demographics","demographic","confounds","consequences","preferred","differences","quantitative","partially","variables","locations","acquisition","geolocation","coordinates","algorithmic","containing","distributions","statistical","distinguishing","faithfulness","adjustments","maximizing","conditionals","hypothesis","exponential","hypotheses","sometimes","equivalent","conditional","distinguish","incorporate","extensive","sentences","appropriate","communities","embedding","improving","retrieval","representational","generative","processing","eliminates","discriminative","customized","replacement","transform","preserving","potentially","efficien ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	semiparametric
# 	frequentist
# 	california
# 	repertoires
# 	sinusoidal
# 	blockmodel
# 	factorizes
# 	martingale
# 	periodicity
# 	spectrometry
# 	contrasted
# 	similitude
# 	regressions
# 	oscillates
# 	injecting
# 	realizations
# 	frontiers
# 	physiologic
# 	triangulations
# 	scleroderma
# Some words which never appear in Statistics papers:
# 	reproduction
# 	deformation
# 	corrective
# 	undiscovered
# 	linguistic
# 	demographics
# 	confounds
# 	geolocation
# 	reordering
# 	disentangling
# 	illuminations
# 	identities
# 	attribution
# 	mammographic
# 	mammogram
# 	textureless
# 	reflective
# 	radiometrically
# 	automobile
# 	revolutionary

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.072574202666995e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
